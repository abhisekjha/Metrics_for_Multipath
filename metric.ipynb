# %%
import matplotlib.pyplot as plt
import numpy as np


number_of_paths_varying = np.array([1, 2, 3, 4])
# bandwidth_utilization_varying = np.array([70, 80, 90, 95])
# computational_overhead_varying = np.array([10, 20, 30, 40])
# effective_throughput_varying = np.array([65, 62, 60, 58])
reconstruction_success_rate_varying = np.array([70, 90, 95, 98])
reconstruction_time_varying = np.array([150, 120, 100, 90])


fig, ax = plt.subplots(2, 3, figsize=(18, 12))

# # Bandwidth Utilization 
# ax[0, 0].plot(number_of_paths_varying, bandwidth_utilization_varying, marker='o', linestyle='-', color='b')
# ax[0, 0].set_title('Bandwidth Utilization ')
# ax[0, 0].set_xlabel('Number of Paths')
# ax[0, 0].set_ylabel('Bandwidth Utilization (%)')
# ax[0, 0].grid(True)
# ax[0, 0].set_xticks(number_of_paths_varying)

# # Computational Overhead 
# ax[0, 1].plot(number_of_paths_varying, computational_overhead_varying, marker='o', linestyle='-', color='r')
# ax[0, 1].set_title('Computational Overhead ')
# ax[0, 1].set_xlabel('Number of Paths')
# ax[0, 1].set_ylabel('Computational Overhead (%)')
# ax[0, 1].grid(True)
# ax[0, 1].set_xticks(number_of_paths_varying)

# # Effective Throughput 
# ax[0, 2].plot(number_of_paths_varying, effective_throughput_varying, marker='o', linestyle='-', color='g')
# ax[0, 2].set_title('Effective Throughput ')
# ax[0, 2].set_xlabel('Number of Paths')
# ax[0, 2].set_ylabel('Effective Throughput (Mbps)')
# ax[0, 2].grid(True)
# ax[0, 2].set_xticks(number_of_paths_varying)

# Reconstruction Success Rate 
ax[1, 0].plot(number_of_paths_varying, reconstruction_success_rate_varying, marker='o', linestyle='-', color='m')
ax[1, 0].set_title('Reconstruction Success Rate ')
ax[1, 0].set_xlabel('Number of Paths')
ax[1, 0].set_ylabel('Reconstruction Success Rate (%)')
ax[1, 0].grid(True)
ax[1, 0].set_xticks(number_of_paths_varying)

# Reconstruction Time 
ax[1, 1].plot(number_of_paths_varying, reconstruction_time_varying, marker='o', linestyle='-', color='c')
ax[1, 1].set_title('Reconstruction Time ')
ax[1, 1].set_xlabel('Number of Paths')
ax[1, 1].set_ylabel('Reconstruction Time (ms)')
ax[1, 1].grid(True)
ax[1, 1].set_xticks(number_of_paths_varying)


ax[1, 2].axis('off')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

probability_of_failure = np.linspace(0, 1, 50)

# reconstruction_rate_1 = 1- probability_of_failure **2
# reconstruction_rate_2= 1- probability_of_failure **3
# reconstruction_rate_3 = 1- probability_of_failure **4

reconstruction_rate_1 = 1 - probability_of_failure  
reconstruction_rate_2 = np.ones_like(probability_of_failure) 
reconstruction_rate_3 = np.ones_like(probability_of_failure)  

plt.figure(figsize=(10,6))

plt.plot(probability_of_failure, reconstruction_rate_1, label="Having 1 Path", marker= "s", linestyle= "--")
plt.plot(probability_of_failure, reconstruction_rate_2, label="Having 2 Paths", marker= "o", linestyle= ":")
plt.plot(probability_of_failure, reconstruction_rate_3, label="Having 3 Paths", marker= "^", linestyle= ":")

plt.title("Reconstruction Rate vs. Probabilities of Path Failing")
plt.xlabel("Probabilities of a Path Failing")
plt.ylabel("Reconstruction Rate")
plt.grid(True)
plt.legend()
plt.xticks(np.arange(0, 1.10, .10))
plt.yticks(np.arange(0, 1.10, .10))

plt.show()
